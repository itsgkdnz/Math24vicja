# %% [markdown]
# # Vectors - Projections and Divisions
#
#
# ## Projecting a Vector onto Another Vector
#
# Projecting vector $\mathbf{a}$ onto axis $\mathbf{b}$ involves finding the component of vector $\mathbf{a}$ along the direction of $\mathbf{b}$.
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$
# \text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b}
# $$
#
#
# ## Projecting a Vector onto Axes
#
# Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a}$ onto the $OX$ axis:
#
# $$
# \text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i}
# $$
#
# Projection of $\mathbf{a}$ onto the $OY$ axis:
#
# $$
# \text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j}
# $$
#
# Recall that $\mathbf{i} = (1, 0)$ and $\mathbf{j} = (0, 1)$ are unit vectors along the $OX$ and $OY$ axes.
#
#
# ## Dividing a Line Segment in a Given Ratio
#
# A line segment is defined by two points in space.
#
# Line segments and vectors are closely related because a line segment connecting two points can be treated as a vector directed from one point to another.
#
# If point \( P \) divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
# $$
# P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)
# $$
#
# **Example:**
#
# Given a line segment connecting points $A(1, 2)$ and $B(3, 8)$, find point $P$ that divides the segment in the ratio 2:3.
#
# Coordinates of point $P$:
# $$
# P = \left(\frac{2 \times 3 + 3 \times 1}{2+3}, \frac{2 \times 8 + 3 \times 2}{2+3}\right) = \left(\frac{9}{5}, \frac{22}{5}\right)
# $$

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (1, 2)
B = (3, 8)

# Ratio m:n
m, n = 2, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, 2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, 8)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [raw]
# ---

# %% [markdown]
# ## Student Exercises
#
# - Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$ in the ratio $1:3$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (2,3)$ onto vector $\mathbf{b} = (1, 1)$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{b} = (1, 1)$ onto vector $\mathbf{a} = (2, 3)$. Illustrate the result on a graph.

# %% [markdown]
# # Exercise 1
#
# # Step 1
#
# Use the section formula:
#
# $$ P(x,y) = \frac{(m.x_2 + n.x_1)}{m + n} , \frac{(m.y_2 + n.y_1)}{m + n} $$
#
# in this case:
#
# <br>
# $A(x_1,y1)=(-1,2)$ <br>
#
# $B(x_2,y_2)=(3,-2)$ <br>
#
# Ratio $ m:n = 1:3,  m=1, n=3$
#
# # Step 2
#
# Calculate:
#
# $$ P(x,y) = \frac{(1.3 + 3.-1)}{1 + 3} = 0 , \frac{(1.-2 + 3.2)}{1 + 3} = 1 $$
#
# According to this calculation
#
# <br> $P(x,y) = P(0,1)$

# %%
import matplotlib.pyplot as plt


A = (-1, 2)
B = (3, -2)

m, n = 1, 3

x = (m * B[0] + n * A[0]) / (m + n)

y = (m * B[1] + n * A[1]) / (m + n)

P = (x, y)

# The graph
plt.figure(figsize=(6, 6))
plt.plot([A[0], B[0]], [A[1], B[1]], 'b--', label="Line Segment AB")  # Line segment AB
plt.scatter(*A, color='red', label='Point A (-1, 2)')
plt.scatter(*B, color='green', label='Point B (3, -2)')
plt.scatter(*P, color='orange', label=f'Point P ({P[0]:.2f}, {P[1]:.2f})')

# Labels and grid
plt.text(A[0], A[1], "A", fontsize=12, ha='right')
plt.text(B[0], B[1], "B", fontsize=12, ha='left')
plt.text(P[0], P[1], "P", fontsize=12, ha='left')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title("Line Segment Division in Ratio 1:3")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

#Print the point P
print("The point dividing the line segment in the ratio 1:3 is:", P)
# Out:
# The point dividing the line segment in the ratio 1:3 is: (0.0, 1.0)

# %% [markdown]
# # Exercise 2
#
# # Step 1
#
# For vector $ a = (x,y)$ <br>
# The projection onto $OX$ is $(x,0)$ <br>
# The projection onto $OY$ is $(0,y)$
#
# <br>
# Thus;
#
# Projection onto $OX = (3,0)$ <br>
# Projection onto $OY = (0,4)$
#
#
# # Final step
#
# The graph:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vector
a = np.array([3, 4])

# Projections onto OX and OY axes
proj_OX = np.array([a[0], 0])  # (3, 0)
proj_OY = np.array([0, a[1]])  # (0, 4)

# Plot the original vector
plt.figure(figsize=(6, 6))
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector a=(3,4)')
plt.quiver(0, 0, proj_OX[0], proj_OX[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection onto OX')
plt.quiver(0, 0, proj_OY[0], proj_OY[1], angles='xy', scale_units='xy', scale=1, color='green', label='Projection onto OY')

#labels and grid
plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title("Vector and its Projections onto OX and OY Axes")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# Display projections
proj_OX, proj_OY
# Out:
# (array([3, 0]), array([0, 4]))

# %% [markdown]
# # Excercise 3
#
# # Step 1
#
# The projection of a to b is given by:A
# $$\frac{(a.b)}{b.b}b$$
#
# # Step 2
#
# Calculate the dot product of a.b
# $$a.b = (2)(1)+(3)(1) = 2 + 3 = 5$$ <br>
#
# Calculate the b.b:
# $$b.b = (1)(1)+(1)(1) = 1+1 = 2 $$ <br>
#
# Scalar $k$:
# $$ k = \frac{a.b}{b.b} =\frac{5}{2} = 2.5 $$
# <br>
# Multiply $k$ with $b$ to get projection : <br>
#
# $$ k.b=2.5 . (1,1) = (2.5,2.5)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vectors
a = np.array([2, 3])
b = np.array([1, 1])

# Calculate projection
dot_product = np.dot(a, b)  # a . b
magnitude_b_squared = np.dot(b, b)  # b . b
k = dot_product / magnitude_b_squared
projection = k * b

# Plot the graph
plt.figure(figsize=(6, 6))
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector a=(2,3)')
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label='Vector b=(1,1)')
plt.quiver(0, 0, projection[0], projection[1], angles='xy', scale_units='xy', scale=1, color='red', label=f'Projection (2.5, 2.5)')

# Add labels and grid
plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title("Projection of Vector a onto Vector b")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# Display the projection result
projection
# Out:
# array([2.5, 2.5])

# %% [markdown]
# # Excercise 4
#
# # Step 1
#
# The projection of b to a is given by:
# $$\frac{(b.a)}{a.a}a$$
#
# # Step 2
#
# Calculate the dot product of b.a
# $$a.b = (1)(2)+(1)(3) = 2 + 3 = 5$$ <br>
#
# Calculate the a.a:
# $$b.b = (2)(2)+(3)(3) = 4 + 9 = 13 $$ <br>
#
# Scalar $k$:
# $$ k = \frac{b.a}{a.a} =\frac{5}{13} = 0.3846 $$
# <br>
# Multiply $k$ with $b$ to get projection : <br>
#
# $$ k.a=0.3846 . (2,3) = (0.7692,1.1538)$$
#
# The graph:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Vectors
b = np.array([1, 1])
a = np.array([2, 3])

# Calculate projection
dot_product = np.dot(b, a)  # b . a
magnitude_a_squared = np.dot(a, a)  # a . a
k = dot_product / magnitude_a_squared
projection = k * a

# Plot the graph
plt.figure(figsize=(6, 6))
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector b=(1,1)')
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='green', label='Vector a=(2,3)')
plt.quiver(0, 0, projection[0], projection[1], angles='xy', scale_units='xy', scale=1, color='red', label=f'Projection (0.77, 1.15)')

# Add labels and grid
plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title("Projection of Vector b onto Vector a")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# Display the projection result
projection
# Out:
# array([0.76923077, 1.15384615])
